# %%
import pandas as pd

df1 = pd.read_csv('../makeDataset/dataset/processedData/31_1.csv')
df2 = pd.read_csv('../makeDataset/dataset/no_NaN_dataset_final.csv')

# %%
df1.head()
# Out:
#   행정구역(시도) 행정구역(시군구)    연도  총인구수(명)  유치원 수  초등학교 수  출생건수  사망건수  혼인건수  이혼건수  \
# 0    서울특별시       종로구  2010   170578     17      14  1107   852  1011   396
# 1    서울특별시        중구  2010   132822     13      12  1170   671  1049   378
# 2    서울특별시       용산구  2010   244853     19      15  2312  1086  1784   528
# 3    서울특별시       성동구  2010   309093     31      20  2886  1226  2306   672
# 4    서울특별시       광진구  2010   375463     42      22  3366  1290  2672   811
#
#    학령인구(명)  총인구수-학령인구(명)       행정구역
# 0    29164        141414  서울특별시 종로구
# 1    19628        113194   서울특별시 중구
# 2    37318        207535  서울특별시 용산구
# 3    51562        257531  서울특별시 성동구
# 4    67422        308041  서울특별시 광진구

# %%
df2.head()
# Out:
#   행정구역(시도) 행정구역(시군구)    연도  총인구수(명)  유치원 수  초등학교 수  출생건수  사망건수  혼인건수  이혼건수  \
# 0    서울특별시       종로구  2010   170578     17      14  1107   852  1011   396
# 1    서울특별시        중구  2010   132822     13      12  1170   671  1049   378
# 2    서울특별시       용산구  2010   244853     19      15  2312  1086  1784   528
# 3    서울특별시       성동구  2010   309093     31      20  2886  1226  2306   672
# 4    서울특별시       광진구  2010   375463     42      22  3366  1290  2672   811
#
#    학령인구(명)  총인구수-학령인구(명)       행정구역
# 0    29164        141414  서울특별시 종로구
# 1    19628        113194   서울특별시 중구
# 2    37318        207535  서울특별시 용산구
# 3    51562        257531  서울특별시 성동구
# 4    67422        308041  서울특별시 광진구

# %%
df1.equals(df2)
# Out:
# False

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2899 entries, 0 to 2898
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      2899 non-null   object
#  1   행정구역(시군구)     2899 non-null   object
#  2   연도            2899 non-null   int64
#  3   총인구수(명)       2899 non-null   int64
#  4   유치원 수         2899 non-null   int64
#  5   초등학교 수        2899 non-null   int64
#  6   출생건수          2899 non-null   int64
#  7   사망건수          2899 non-null   int64
#  8   혼인건수          2899 non-null   int64
#  9   이혼건수          2899 non-null   int64
#  10  학령인구(명)       2899 non-null   int64
#  11  총인구수-학령인구(명)  2899 non-null   int64
#  12  행정구역          2899 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 294.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2899 entries, 0 to 2898
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      2899 non-null   object
#  1   행정구역(시군구)     2899 non-null   object
#  2   연도            2899 non-null   int64
#  3   총인구수(명)       2899 non-null   int64
#  4   유치원 수         2899 non-null   int64
#  5   초등학교 수        2899 non-null   int64
#  6   출생건수          2899 non-null   int64
#  7   사망건수          2899 non-null   int64
#  8   혼인건수          2899 non-null   int64
#  9   이혼건수          2899 non-null   int64
#  10  학령인구(명)       2899 non-null   int64
#  11  총인구수-학령인구(명)  2899 non-null   int64
#  12  행정구역          2899 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 294.6+ KB

# %%
(df1 == df2).count()
# Out:
# 행정구역(시도)        2899
# 행정구역(시군구)       2899
# 연도              2899
# 총인구수(명)         2899
# 유치원 수           2899
# 초등학교 수          2899
# 출생건수            2899
# 사망건수            2899
# 혼인건수            2899
# 이혼건수            2899
# 학령인구(명)         2899
# 총인구수-학령인구(명)    2899
# 행정구역            2899
# dtype: int64

# %%
import pandas as pd

# 두 데이터 프레임 df1, df2
different_rows = pd.concat([df1, df2]).drop_duplicates(keep=False)

# %%
merged_df = pd.merge(df1, df2, how='outer', indicator=True)
different_rows = merged_df[merged_df['_merge'] != 'both']

# %%
mask = df1.ne(df2).any(axis=1)
different_rows = df1[mask]
different_rows
# Out:
#      행정구역(시도) 행정구역(시군구)    연도  총인구수(명)  유치원 수  초등학교 수  출생건수  사망건수  혼인건수  이혼건수  \
# 26      부산광역시        서구  2010    62594     16      17   609   459   449   142
# 42      대구광역시        서구  2010   607083     74      51  5404  2400  3366  1116
# 48      인천광역시        동구  2010   473423     68      33  4653  1877  3088  1288
# 96        경기도       양주시  2010   564141     90      53  5821  2404  3220  1365
# 249     부산광역시        서구  2011    64733     12      16   567   467   399   163
# 265     대구광역시        서구  2011   606542     77      52  5333  2472  3265  1039
# 271     인천광역시        동구  2011   495469     71      36  5010  1994  3200  1135
# 319       경기도       양주시  2011   578485     92      54  6125  2409  3292  1485
# 472     부산광역시        서구  2012    65806     12      16   671   418   418   165
# 488     대구광역시        서구  2012   606557     80      52  5463  2462  3322  1042
# 494     인천광역시        동구  2012   503597     71      36  5333  2164  3224  1384
# ...
