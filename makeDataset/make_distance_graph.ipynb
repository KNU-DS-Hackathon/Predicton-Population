# %%
import pandas as pd

# %%
filePath = './dataset/adjacency_matrix.csv'
distance_matrix = pd.read_csv(filePath, index_col=0)

distance_matrix.head()
# Out:
#             강원강릉시       강원고성군       강원동해시       강원삼척시      강원속초시       강원양구군  \
# docity
# 강원강릉시    0.000000   78.530302   32.832761   42.145885  56.412485   87.339480
# 강원고성군   78.530302    0.000000  110.785057  120.233443  22.138478   51.457336
# 강원동해시   32.832761  110.785057    0.000000    9.454969  88.658337  118.287305
# 강원삼척시   42.145885  120.233443    9.454969    0.000000  98.104205  126.718841
# 강원속초시   56.412485   22.138478   88.658337   98.104205   0.000000   53.723255
#
#             강원양양군       강원영월군       강원원주시       강원인제군  ...       충청음성군  \
# docity                                                 ...
# 강원강릉시   42.478539   73.013896   95.861557   71.297142  ...  138.334056
# 강원고성군   36.408490  133.112542  125.138624   43.255624  ...  174.191634
# 강원동해시   75.141194   69.035839  107.420730  102.723800  ...  141.840711
# 강원삼척시   84.535489   68.895896  110.677986  111.351218  ...  142.403432
# 강원속초시   14.807813  114.373119  112.894017   39.898501  ...  161.730278
#
#              충청제천시       충청증평군       충청진천군       충청천안시       충청청양군  \
# docity
# 강원강릉시    91.674595  157.151627  161.804535  185.372602  233.452786
# 강원고성군   140.912805  193.888417  192.458313  210.006736  259.421519
# 강원동해시    92.569542  158.847038  166.314778  191.474382  237.099618
# 강원삼척시    93.137346  158.736792  166.957057  192.415783  237.133637
# 강원속초시   124.583847  181.542495  181.635948  201.022903  250.637464
#
#              충청청주시       충청충주시       충청태안군       충청홍성군
# docity
# 강원강릉시   177.343533  119.216734  254.188657  234.314919
# 강원고성군   216.662892  161.729110  263.910596  254.120378
# 강원동해시   176.520998  120.774804  264.289199  240.721546
# 강원삼척시   175.556918  121.025102  266.104274  241.538867
# 강원속초시   203.966333  147.404910  259.605572  246.947901
#
# [5 rows x 223 columns]

# %%
distance_threshold = 31
local_params = 1
adj_params = 1 - local_params

# %%
dm_with_threshhold = distance_matrix[distance_matrix < distance_threshold]

# %%
dm_with_threshhold.head()
# Out:
#         강원강릉시      강원고성군     강원동해시     강원삼척시      강원속초시  강원양구군      강원양양군  \
# docity
# 강원강릉시     0.0        NaN       NaN       NaN        NaN    NaN        NaN
# 강원고성군     NaN   0.000000       NaN       NaN  22.138478    NaN        NaN
# 강원동해시     NaN        NaN  0.000000  9.454969        NaN    NaN        NaN
# 강원삼척시     NaN        NaN  9.454969  0.000000        NaN    NaN        NaN
# 강원속초시     NaN  22.138478       NaN       NaN   0.000000    NaN  14.807813
#
#         강원영월군  강원원주시  강원인제군  ...  충청음성군  충청제천시  충청증평군  충청진천군  충청천안시  충청청양군  \
# docity                       ...
# 강원강릉시     NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#         충청청주시  충청충주시  충청태안군  충청홍성군
# docity
# 강원강릉시     NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN    NaN    NaN
#
# [5 rows x 223 columns]

# %%
# dm_with_threshhold의 모든 가중치를 역수로 취하기.
# 가중치가 0일경우 1로 바꾸기.

dm_with_threshhold = dm_with_threshhold.replace(0, 1)
dm_with_threshhold = 1 / dm_with_threshhold

dm_with_threshhold.head()
# Out:
#         강원강릉시    강원고성군     강원동해시     강원삼척시    강원속초시  강원양구군     강원양양군  강원영월군  \
# docity
# 강원강릉시     1.0      NaN       NaN       NaN      NaN    NaN       NaN    NaN
# 강원고성군     NaN  1.00000       NaN       NaN  0.04517    NaN       NaN    NaN
# 강원동해시     NaN      NaN  1.000000  0.105764      NaN    NaN       NaN    NaN
# 강원삼척시     NaN      NaN  0.105764  1.000000      NaN    NaN       NaN    NaN
# 강원속초시     NaN  0.04517       NaN       NaN  1.00000    NaN  0.067532    NaN
#
#         강원원주시  강원인제군  ...  충청음성군  충청제천시  충청증평군  충청진천군  충청천안시  충청청양군  충청청주시  \
# docity                ...
# 강원강릉시     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         충청충주시  충청태안군  충청홍성군
# docity
# 강원강릉시     NaN    NaN    NaN
# 강원고성군     NaN    NaN    NaN
# 강원동해시     NaN    NaN    NaN
# 강원삼척시     NaN    NaN    NaN
# 강원속초시     NaN    NaN    NaN
#
# [5 rows x 223 columns]

# %%
import numpy as np

# 각 행의 합을 계산
row_sums = dm_with_threshhold.sum(axis=1) - 1

row_sums.head()
# Out:
# docity
# 강원강릉시    0.000000
# 강원고성군    0.045170
# 강원동해시    0.105764
# 강원삼척시    0.105764
# 강원속초시    0.112702
# dtype: float64

# %%
# 각 인접 도시와의 가중치를 총합으로 나눔
normalized_df = dm_with_threshhold.div(row_sums, axis=0) * adj_params

normalized_df.head()
# Out:
#         강원강릉시  강원고성군  강원동해시  강원삼척시  강원속초시  강원양구군  강원양양군  강원영월군  강원원주시  강원인제군  \
# docity
# 강원강릉시     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    0.0    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    0.0    0.0    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    0.0    0.0    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    0.0    NaN    NaN    0.0    NaN    0.0    NaN    NaN    NaN
#
#         ...  충청음성군  충청제천시  충청증평군  충청진천군  충청천안시  충청청양군  충청청주시  충청충주시  충청태안군  \
# docity  ...
# 강원강릉시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         충청홍성군
# docity
# 강원강릉시     NaN
# 강원고성군     NaN
# 강원동해시     NaN
# 강원삼척시     NaN
# 강원속초시     NaN
#
# [5 rows x 223 columns]

# %%
# 대각선 행 중 inf가 아닌 행은 0.7으로 만들기

for i in range(len(normalized_df)):
    if normalized_df.iloc[i, i] != np.inf:
        normalized_df.iloc[i, i] = local_params
    else:
        normalized_df.iloc[i, i] = 1

normalized_df.head()
# Out:
#         강원강릉시  강원고성군  강원동해시  강원삼척시  강원속초시  강원양구군  강원양양군  강원영월군  강원원주시  강원인제군  \
# docity
# 강원강릉시     1.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    1.0    NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    1.0    0.0    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    0.0    1.0    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    0.0    NaN    NaN    1.0    NaN    0.0    NaN    NaN    NaN
#
#         ...  충청음성군  충청제천시  충청증평군  충청진천군  충청천안시  충청청양군  충청청주시  충청충주시  충청태안군  \
# docity  ...
# 강원강릉시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시   ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         충청홍성군
# docity
# 강원강릉시     NaN
# 강원고성군     NaN
# 강원동해시     NaN
# 강원삼척시     NaN
# 강원속초시     NaN
#
# [5 rows x 223 columns]

# %%
result = normalized_df.sum(axis=1)

result[result - 1 > 0.00001]
# Out:
# Series([], dtype: float64)

# %%
normalized_df.to_csv('./dataset/distance_normalize_v2.csv')

# %%
df = pd.read_csv('./dataset/no_NaN_dataset_final.csv')

df.head()
# Out:
#   행정구역(시도) 행정구역(시군구)    연도  총인구수(명)  유치원 수  초등학교 수  출생건수  사망건수  혼인건수  이혼건수  \
# 0    서울특별시       종로구  2010   170578     17      14  1107   852  1011   396
# 1    서울특별시        중구  2010   132822     13      12  1170   671  1049   378
# 2    서울특별시       용산구  2010   244853     19      15  2312  1086  1784   528
# 3    서울특별시       성동구  2010   309093     31      20  2886  1226  2306   672
# 4    서울특별시       광진구  2010   375463     42      22  3366  1290  2672   811
#
#    학령인구(명)  총인구수-학령인구(명)       행정구역
# 0    29164        141414  서울특별시 종로구
# 1    19628        113194   서울특별시 중구
# 2    37318        207535  서울특별시 용산구
# 3    51562        257531  서울특별시 성동구
# 4    67422        308041  서울특별시 광진구

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2899 entries, 0 to 2898
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      2899 non-null   object
#  1   행정구역(시군구)     2899 non-null   object
#  2   연도            2899 non-null   int64
#  3   총인구수(명)       2899 non-null   int64
#  4   유치원 수         2899 non-null   int64
#  5   초등학교 수        2899 non-null   int64
#  6   출생건수          2899 non-null   int64
#  7   사망건수          2899 non-null   int64
#  8   혼인건수          2899 non-null   int64
#  9   이혼건수          2899 non-null   int64
#  10  학령인구(명)       2899 non-null   int64
#  11  총인구수-학령인구(명)  2899 non-null   int64
#  12  행정구역          2899 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 294.6+ KB

# %%
def find_cityname_in_df(df, cityname, year):
    sido = cityname[:2]
    sigungu = cityname[2:]
    
    #if sido == '부산' and sigungu == '서구':
    #    print('break')
        
    
    result = df[(df['행정구역(시도)'].str.contains(sido)) & 
                (df['행정구역(시군구)'] == sigungu) & 
                (df['연도'] == year)]
    
    if len(result) != 1:
        result = df[(df['행정구역(시도)'].str.contains(sido)) & 
                (df['행정구역(시군구)'].str.contains(sigungu)) & 
                (df['연도'] == year)]

    if len(result) != 1:
        print("길이는 : " + str(len(result)))
        print(result.head())

    return result

def find_normalizedf_row(do, city):
    matching_rows = normalized_df.index[normalized_df.index.str.contains(do) & normalized_df.index.str.contains(city)]
    if matching_rows.empty:
        return pd.DataFrame()
    else:
        return normalized_df.loc[matching_rows].iloc[0]

# %%
from tqdm import tqdm

processed_df = df.copy()
numeric_columns = df.select_dtypes(include=[np.number]).columns
numeric_columns = numeric_columns.drop('학령인구(명)')
error_city_list = []


for i in tqdm(range(len(df))):
    try:
        parts = df.iloc[i]['행정구역(시도)'].split()
        do = parts[0][:2]
        city = df.iloc[i]['행정구역(시군구)']
        year = df.iloc[i]['연도']
        
        if do == '부산' and city == '서구':
            print('break')

        adj_matrix = find_normalizedf_row(do, city)
        row_list = []
        

        weight = 0

        
        #tmp_df = pd.DataFrame(columns=df.columns)
            
        for j in range(len(adj_matrix)):
            try:

                adj_city_name = adj_matrix.index[j]
                adj_city_weight = adj_matrix.iloc[j]
                if pd.isna(adj_city_weight):
                    continue
                
                row = find_cityname_in_df(df, adj_city_name, year)
        
                #tmp_df.insert(row)
                row[numeric_columns] *= adj_city_weight

                
                if(row.empty):
                    error_city_list.append(adj_city_name)
                    continue
                
                row_list.append(row)
            except KeyError:
                print("error 2: " + adj_matrix.index[j])
                continue
        
                
        # Sum all the rows in row_list
        new_row = pd.concat(row_list)
        
        
        new_row = new_row[numeric_columns]
        new_row_sum = new_row.sum()

        #if i == 1:
            #print(yearlist)
            #print(new_row['연도'])
        

        # Use .loc to avoid SettingWithCopyWarning
        processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum

    except Exception as e:
        print(f"error 3:  - {str(e)}")
        print(do + " " + city)
        continue
# Out:
#   0%|          | 0/2899 [00:00<?, ?it/s]/var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_24088/3288908527.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row[numeric_columns] *= adj_city_weight
#   1%|          | 25/2899 [00:04<08:31,  5.62it/s]
# break
#   1%|          | 26/2899 [02:12<4:04:42,  5.11s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb 셀 15 line 1
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=15'>16</a> if do == '부산' and city == '서구':
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a>     print('break')
# ---> <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=18'>19</a> adj_matrix = find_normalizedf_row(do, city)
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=19'>20</a> row_list = []
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=22'>23</a> weight = 0
#
# /Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb 셀 15 line 2
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=23'>24</a> def find_normalizedf_row(do, city):
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=24'>25</a>     matching_rows = normalized_df.index[normalized_df.index.str.contains(do) & normalized_df.index.str.contains(city)]
# ---> <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=25'>26</a>     if matching_rows.empty:
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=26'>27</a>         return pd.DataFrame()
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=27'>28</a>     else:
#
# /Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb 셀 15 line 2
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=23'>24</a> def find_normalizedf_row(do, city):
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=24'>25</a>     matching_rows = normalized_df.index[normalized_df.index.str.contains(do) & normalized_df.index.str.contains(city)]
# ---> <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=25'>26</a>     if matching_rows.empty:
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=26'>27</a>         return pd.DataFrame()
#      <a href='vscode-notebook-cell:/Users/yshong/study/dataScienceOpenning/Predicton-Population/makeDataset/make_distance_graph.ipynb#X20sZmlsZQ%3D%3D?line=27'>28</a>     else:
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1395, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1344, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dataScience/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dataScience/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
processed_df = df.copy()
numeric_columns = df.select_dtypes(include=[np.number]).columns
numeric_columns = numeric_columns.drop('학령인구(명)')
error_city_list = []

for col in numeric_columns:
    processed_df[col] = processed_df[col].astype(float)


# 메인 데이터 처리 루프
for i in tqdm(range(len(df))):
    parts = df.iloc[i]['행정구역(시도)'].split()
    do = parts[0][:2]
    city = df.iloc[i]['행정구역(시군구)']
    year = df.iloc[i]['연도']
    

    try:
        adj_matrix_row = find_normalizedf_row(do, city)
        if adj_matrix_row.empty:
            continue

        tmp_df = pd.DataFrame()
        for adj_city_name in adj_matrix_row.index:
            adj_city_weight = adj_matrix_row[adj_city_name]
            if pd.isna(adj_city_weight):
                continue

# 데이터 조작 전에 .copy() 사용
            row = find_cityname_in_df(df, adj_city_name, year).copy()
            if row.empty:
                error_city_list.append(adj_city_name)
                continue

# 부적합한 데이터 타입 문제 해결
            row[numeric_columns] = row[numeric_columns].astype(float) * adj_city_weight
            tmp_df = pd.concat([tmp_df, row])
            

        new_row_sum = tmp_df[numeric_columns].sum()
        processed_df.loc[i, numeric_columns] = new_row_sum

    except Exception as e:
        print(f"error: {str(e)} - {do} {city}")
        continue
# Out:
# 100%|██████████| 2899/2899 [04:38<00:00, 10.43it/s]

# %%
print(set(error_city_list))
# Out:
# set()

# %%
# procedded_df의 '연도' 컬럼을 반올림해서 int 정수로 바꾸기

processed_df['연도'] = processed_df['연도'].round().astype(int)

# %%
processed_df.to_csv('./dataset/weighted_dataset_laewon2.csv')
