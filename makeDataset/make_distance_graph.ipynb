# %%
import pandas as pd

# %%
filePath = './dataset/adjacency_matrix.csv'
distance_matrix = pd.read_csv(filePath, index_col=0)

distance_matrix.head()
# Out:
#             강원강릉시       강원고성군       강원동해시       강원삼척시      강원속초시       강원양구군  \
# docity
# 강원강릉시    0.000000   78.530302   32.832761   42.145885  56.412485   87.339480
# 강원고성군   78.530302    0.000000  110.785057  120.233443  22.138478   51.457336
# 강원동해시   32.832761  110.785057    0.000000    9.454969  88.658337  118.287305
# 강원삼척시   42.145885  120.233443    9.454969    0.000000  98.104205  126.718841
# 강원속초시   56.412485   22.138478   88.658337   98.104205   0.000000   53.723255
#
#             강원양양군       강원영월군       강원원주시       강원인제군  ...       충청음성군  \
# docity                                                 ...
# 강원강릉시   42.478539   73.013896   95.861557   71.297142  ...  138.334056
# 강원고성군   36.408490  133.112542  125.138624   43.255624  ...  174.191634
# 강원동해시   75.141194   69.035839  107.420730  102.723800  ...  141.840711
# 강원삼척시   84.535489   68.895896  110.677986  111.351218  ...  142.403432
# 강원속초시   14.807813  114.373119  112.894017   39.898501  ...  161.730278
#
#              충청제천시       충청증평군       충청진천군       충청천안시       충청청양군  \
# docity
# 강원강릉시    91.674595  157.151627  161.804535  185.372602  233.452786
# 강원고성군   140.912805  193.888417  192.458313  210.006736  259.421519
# 강원동해시    92.569542  158.847038  166.314778  191.474382  237.099618
# 강원삼척시    93.137346  158.736792  166.957057  192.415783  237.133637
# 강원속초시   124.583847  181.542495  181.635948  201.022903  250.637464
#
#              충청청주시       충청충주시       충청태안군       충청홍성군
# docity
# 강원강릉시   177.343533  119.216734  254.188657  234.314919
# 강원고성군   216.662892  161.729110  263.910596  254.120378
# 강원동해시   176.520998  120.774804  264.289199  240.721546
# 강원삼척시   175.556918  121.025102  266.104274  241.538867
# 강원속초시   203.966333  147.404910  259.605572  246.947901
#
# [5 rows x 223 columns]

# %%
distance_threshold = 60
local_params = 0.7
adj_params = 1 - local_params

# %%
dm_with_threshhold = distance_matrix[distance_matrix < distance_threshold]

# %%
dm_with_threshhold.head()
# Out:
#             강원강릉시      강원고성군      강원동해시      강원삼척시      강원속초시      강원양구군  \
# docity
# 강원강릉시    0.000000        NaN  32.832761  42.145885  56.412485        NaN
# 강원고성군         NaN   0.000000        NaN        NaN  22.138478  51.457336
# 강원동해시   32.832761        NaN   0.000000   9.454969        NaN        NaN
# 강원삼척시   42.145885        NaN   9.454969   0.000000        NaN        NaN
# 강원속초시   56.412485  22.138478        NaN        NaN   0.000000  53.723255
#
#             강원양양군  강원영월군  강원원주시      강원인제군  ...  충청음성군  충청제천시  충청증평군  충청진천군  \
# docity                                      ...
# 강원강릉시   42.478539    NaN    NaN        NaN  ...    NaN    NaN    NaN    NaN
# 강원고성군   36.408490    NaN    NaN  43.255624  ...    NaN    NaN    NaN    NaN
# 강원동해시         NaN    NaN    NaN        NaN  ...    NaN    NaN    NaN    NaN
# 강원삼척시         NaN    NaN    NaN        NaN  ...    NaN    NaN    NaN    NaN
# 강원속초시   14.807813    NaN    NaN  39.898501  ...    NaN    NaN    NaN    NaN
#
#         충청천안시  충청청양군  충청청주시  충청충주시  충청태안군  충청홍성군
# docity
# 강원강릉시     NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 223 columns]

# %%
# dm_with_threshhold의 모든 가중치를 역수로 취하기.
# 가중치가 0일경우 1로 바꾸기.

dm_with_threshhold = dm_with_threshhold.replace(0, 1)
dm_with_threshhold = 1 / dm_with_threshhold

dm_with_threshhold.head()
# Out:
#            강원강릉시    강원고성군     강원동해시     강원삼척시     강원속초시     강원양구군     강원양양군  \
# docity
# 강원강릉시   1.000000      NaN  0.030457  0.023727  0.017727       NaN  0.023541
# 강원고성군        NaN  1.00000       NaN       NaN  0.045170  0.019434  0.027466
# 강원동해시   0.030457      NaN  1.000000  0.105764       NaN       NaN       NaN
# 강원삼척시   0.023727      NaN  0.105764  1.000000       NaN       NaN       NaN
# 강원속초시   0.017727  0.04517       NaN       NaN  1.000000  0.018614  0.067532
#
#         강원영월군  강원원주시     강원인제군  ...  충청음성군  충청제천시  충청증평군  충청진천군  충청천안시  충청청양군  \
# docity                          ...
# 강원강릉시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN  0.023118  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN  0.025064  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#         충청청주시  충청충주시  충청태안군  충청홍성군
# docity
# 강원강릉시     NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN    NaN    NaN
#
# [5 rows x 223 columns]

# %%
import numpy as np

# 각 행의 합을 계산
row_sums = dm_with_threshhold.sum(axis=1) - 1

row_sums.head()
# Out:
# docity
# 강원강릉시    0.117457
# 강원고성군    0.115188
# 강원동해시    0.183397
# 강원삼척시    0.197967
# 강원속초시    0.174106
# dtype: float64

# %%
# 각 인접 도시와의 가중치를 총합으로 나눔
normalized_df = dm_with_threshhold.div(row_sums, axis=0) * adj_params

normalized_df.head()
# Out:
#            강원강릉시     강원고성군     강원동해시     강원삼척시     강원속초시     강원양구군     강원양양군  \
# docity
# 강원강릉시   2.554137       NaN  0.077792  0.060602  0.045276       NaN  0.060128
# 강원고성군        NaN  2.604431       NaN       NaN  0.117643  0.050613  0.071534
# 강원동해시   0.049822       NaN  1.635796  0.173009       NaN       NaN       NaN
# 강원삼척시   0.035956       NaN  0.160276  1.515404       NaN       NaN       NaN
# 강원속초시   0.030544  0.077832       NaN       NaN  1.723086  0.032073  0.116363
#
#         강원영월군  강원원주시     강원인제군  ...  충청음성군  충청제천시  충청증평군  충청진천군  충청천안시  충청청양군  \
# docity                          ...
# 강원강릉시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN  0.060210  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN  0.043187  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#         충청청주시  충청충주시  충청태안군  충청홍성군
# docity
# 강원강릉시     NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN    NaN    NaN
#
# [5 rows x 223 columns]

# %%
# 대각선 행은 0.7으로 만들기

np.fill_diagonal(normalized_df.values, local_params)

# %%
# '경상울릉군'은 0.7이 아니라 1로 만들기

normalized_df.loc['경상울릉군', '경상울릉군'] = 1

# %%
normalized_df.head()
# Out:
#            강원강릉시     강원고성군     강원동해시     강원삼척시     강원속초시     강원양구군     강원양양군  \
# docity
# 강원강릉시   0.700000       NaN  0.077792  0.060602  0.045276       NaN  0.060128
# 강원고성군        NaN  0.700000       NaN       NaN  0.117643  0.050613  0.071534
# 강원동해시   0.049822       NaN  0.700000  0.173009       NaN       NaN       NaN
# 강원삼척시   0.035956       NaN  0.160276  0.700000       NaN       NaN       NaN
# 강원속초시   0.030544  0.077832       NaN       NaN  0.700000  0.032073  0.116363
#
#         강원영월군  강원원주시     강원인제군  ...  충청음성군  충청제천시  충청증평군  충청진천군  충청천안시  충청청양군  \
# docity                          ...
# 강원강릉시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN  0.060210  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN  0.043187  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#         충청청주시  충청충주시  충청태안군  충청홍성군
# docity
# 강원강릉시     NaN    NaN    NaN    NaN
# 강원고성군     NaN    NaN    NaN    NaN
# 강원동해시     NaN    NaN    NaN    NaN
# 강원삼척시     NaN    NaN    NaN    NaN
# 강원속초시     NaN    NaN    NaN    NaN
#
# [5 rows x 223 columns]

# %%
result = normalized_df.sum(axis=1)

result
# Out:
# docity
# 강원강릉시    1.0
# 강원고성군    1.0
# 강원동해시    1.0
# 강원삼척시    1.0
# 강원속초시    1.0
#         ...
# 충청청양군    1.0
# 충청청주시    1.0
# 충청충주시    1.0
# 충청태안군    1.0
# 충청홍성군    1.0
# Length: 223, dtype: float64

# %%
normalized_df.to_csv('./dataset/distance_normalize_v2.csv')

# %%
df = pd.read_csv('./dataset/no_NaN_dataset_final.csv')

df.head()
# Out:
#   행정구역(시도) 행정구역(시군구)    연도  총인구수(명)  유치원 수  초등학교 수  출생건수  사망건수  혼인건수  이혼건수  \
# 0    서울특별시       종로구  2010   170578     17      14  1107   852  1011   396
# 1    서울특별시        중구  2010   132822     13      12  1170   671  1049   378
# 2    서울특별시       용산구  2010   244853     19      15  2312  1086  1784   528
# 3    서울특별시       성동구  2010   309093     31      20  2886  1226  2306   672
# 4    서울특별시       광진구  2010   375463     42      22  3366  1290  2672   811
#
#    학령인구(명)  총인구수-학령인구(명)       행정구역
# 0    29164        141414  서울특별시 종로구
# 1    19628        113194   서울특별시 중구
# 2    37318        207535  서울특별시 용산구
# 3    51562        257531  서울특별시 성동구
# 4    67422        308041  서울특별시 광진구

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2899 entries, 0 to 2898
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      2899 non-null   object
#  1   행정구역(시군구)     2899 non-null   object
#  2   연도            2899 non-null   int64
#  3   총인구수(명)       2899 non-null   int64
#  4   유치원 수         2899 non-null   int64
#  5   초등학교 수        2899 non-null   int64
#  6   출생건수          2899 non-null   int64
#  7   사망건수          2899 non-null   int64
#  8   혼인건수          2899 non-null   int64
#  9   이혼건수          2899 non-null   int64
#  10  학령인구(명)       2899 non-null   int64
#  11  총인구수-학령인구(명)  2899 non-null   int64
#  12  행정구역          2899 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 294.6+ KB

# %%
def find_cityname_in_df(df, cityname, year):
    # cityname에서 첫 두글자는 시도에, 나머지는 시군구에 저장함
    
    sido = cityname[:2]
    sigungu = cityname[2:]
    
    # sido와 sigungu를 모두 포함하는 행 찾기 꼭 일치하지 않아도 되고 일부만 포함해도 됨
    
    sido_df = df[df['행정구역(시도)'].str.contains(sido)]
    # sigungu_df = sido_df[sido_df['행정구역(시군구)'].str.contains(sigungu)]
    sigungu_df = sido_df[sido_df['행정구역(시군구)'] == sigungu]
    
    
    result = sigungu_df[sigungu_df['연도'] == year]
    
    if len(result) == 0:
        sido = cityname[:2]
        sigungu = cityname[2:]
        
        sido_df = df[df['행정구역(시도)'].str.contains(sido)]
        
        sigungu_df = sido_df[sido_df['행정구역(시군구)'].str.contains(sigungu)]
        
        result = sigungu_df[sigungu_df['연도'] == year]
        
    if len(result) != 1:
        print("길이는 : " + str(len(result)))
        print(result.head())

    return result

# %%
def find_normalizedf_row(do, city):
    row_names = normalized_df.index
    for row_name in row_names:
        if do in row_name and city in row_name:
            return normalized_df.loc[row_name]

# %%
processed_df = df.copy()
numeric_columns = df.select_dtypes(include=[np.number]).columns
error_city_list = []

rawYearList = list()
processedYearList = list()

for i in range(len(df)):
    try:
        parts = df.iloc[i]['행정구역(시도)'].split()
        do = parts[0][:2]
        city = df.iloc[i]['행정구역(시군구)']
        year = df.iloc[i]['연도']

        adj_matrix = find_normalizedf_row(do, city)
        row_list = []
        

        weight = 0

        
        #tmp_df = pd.DataFrame(columns=df.columns)
            
        for j in range(len(adj_matrix)):
            try:

                adj_city_name = adj_matrix.index[j]
                adj_city_weight = adj_matrix.iloc[j]
                if pd.isna(adj_city_weight):
                    continue
                
                

                row = find_cityname_in_df(df, adj_city_name, year)
        
                if i == 0:
                    rawYearList.append(row['연도'])
                    
                
                #tmp_df.insert(row)
                row[numeric_columns] *= adj_city_weight
                

                
                if i == 0:
                    weight = adj_city_weight
                    processedYearList.append(row['연도'])
                
                if(row.empty):
                    error_city_list.append(adj_city_name)
                    continue
                
                row_list.append(row)
            except KeyError:
                print("error 2: " + adj_matrix.index[j])
                continue
        
                
        # Sum all the rows in row_list
        new_row = pd.concat(row_list)
        
        if i == 0:
            print(new_row.head())
        
        new_row = new_row[numeric_columns]
        new_row_sum = new_row.sum()

        #if i == 1:
            #print(yearlist)
            #print(new_row['연도'])
        

        # Use .loc to avoid SettingWithCopyWarning
        processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum

    except Exception as e:
        print(f"error 3:  - {str(e)}")
        print(do + " " + city)
        continue
# Out:
#    행정구역(시도) 행정구역(시군구)        연도      총인구수(명)     유치원 수    초등학교 수       출생건수  \
# 99      경기도       가평군  2.245737    65.796739  0.020111  0.014525   0.465907
# 54    인천광역시       강화군  2.596484    86.683818  0.032295  0.028419   0.455999
# 80      경기도       고양시  6.037986  2854.120112  0.444588  0.231306  24.872899
# 81      경기도       과천시  7.675625   276.013187  0.026731  0.015275   2.203401
# 76      경기도       광명시  8.421045  1441.138250  0.196910  0.096360  16.410564
#
#          사망건수       혼인건수      이혼건수     학령인구(명)  총인구수-학령인구(명)       행정구역
# 99   0.640203   0.369820  0.151950   10.748253     55.048486    경기도 가평군
# 54   0.926209   0.390119  0.151139   12.853243     73.830576  인천광역시 강화군
# 80  11.075650  16.122325  6.046998  657.960276   2196.159835    경기도 고양시
# 81   0.905036   1.401470  0.313135   64.467613    211.545574    경기도 과천시
# 76   5.471584  11.931908  2.798636  285.050277   1156.087973    경기도 광명시
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '232512.76714797315' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '23.836316336256843' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '17.320714083860025' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1827.3644457766782' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1048.2681073666' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1474.4813682645283' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '527.0544935609084' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '41542.945652816954' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '190969.82149515618' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum
# /var/folders/39/yhddl2n53db5kx8yl47wsn_m0000gn/T/ipykernel_2142/534177094.py:74: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2009.9999999999998' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   processed_df.loc[processed_df.index[i], numeric_columns] = new_row_sum

# %%
print(set(error_city_list))
# Out:
# set()

# %%
processed_df.to_csv('./dataset/weighted_dataset_v4.csv')

# %%
rawYearList
# Out:
# []
